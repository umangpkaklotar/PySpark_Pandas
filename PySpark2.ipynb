# %% [markdown]
# <a href="https://colab.research.google.com/github/umangpkaklotar/PySpark_Pandas/blob/main/PySpark2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark # import the pyspark

# %%
from pyspark.sql import SparkSession # create the session for sparkSession

# %%
spark = SparkSession.builder.appName('dataframe').getOrCreate() # create the app and name for app
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://8181b100824b:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.option('header','true').csv('/content/test1.csv',inferSchema=True)
df.printSchema()
#this is show the data type for the data  like this output
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df_pyspark = spark.read.csv('/content/test1.csv',header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df_pyspark.select('name','age').show()
# this is show the onliy name colum
# Out:
# +--------+---+
# |    name|age|
# +--------+---+
# |     Ben| 31|
# |Srikanth| 30|
# |   Sunny| 29|
# |    Paul| 24|
# |  Harish| 21|
# |   Shiva| 23|
# +--------+---+

# %%
df_pyspark.filter(df_pyspark['age'] == 23).show()
# this is use the filter and show the data wher age is 23
# Out:
# +-----+---+----------+------+
# | Name|age|Experience|Salary|
# +-----+---+----------+------+
# |Shiva| 23|         2| 18000|
# +-----+---+----------+------+

# %%
df_pyspark.dtypes
#  this is the chacke the data type
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df_pyspark.describe().show()
# describe is use for the min , max, mean, count, like show the
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
ord('u')
# ord use for ascil values
# Out:
# 104

# %%
# adding columns  in data frame
df_pyspark= df_pyspark.withColumn('Experience After 2 year',df_pyspark['Experience']+2)

# %%
df_pyspark.show()
# Out:
# +--------+---+----------+------+-----------------------+
# |    Name|age|Experience|Salary|Experience After 2 year|
# +--------+---+----------+------+-----------------------+
# |     Ben| 31|        10| 30000|                     12|
# |Srikanth| 30|         8| 25000|                     10|
# |   Sunny| 29|         4| 20000|                      6|
# |    Paul| 24|         3| 20000|                      5|
# |  Harish| 21|         1| 15000|                      3|
# |   Shiva| 23|         2| 18000|                      4|
# +--------+---+----------+------+-----------------------+

# %%
# drop the columns
df_pyspark= df_pyspark.drop('Experience After 2 year')

# %%
df_pyspark.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
# Rename the columns
df_pyspark.withColumnRenamed('name','new name').show()
# Out:
# +--------+---+----------+------+
# |new name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+
