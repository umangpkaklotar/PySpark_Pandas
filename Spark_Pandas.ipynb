# %% [markdown]
# <a href="https://colab.research.google.com/github/umangpkaklotar/PySpark_Pandas/blob/main/Spark_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import pandas as pd

# %%
df = pd.read_csv('/content/test1.csv') # read the dataframe from pandas
df.head() # by deffold first 5 data show
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000
# 2     Sunny   29           4   20000
# 3      Paul   24           3   20000
# 4    Harish   21           1   15000

# %%
df.shape # show the row and colum for data how mucha row and colum in the data
# Out:
# (6, 4)

# %%
df.info() # show the
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   age         6 non-null      int64
#  2   Experience  6 non-null      int64
#  3   Salary      6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 324.0+ bytes

# %%
type(pd.read_csv('/content/test1.csv')) # show the doumetetion for pandas
# Out:
# pandas.core.frame.DataFrame

# %%
from pyspark.sql import SparkSession # import the saprk and add spark Session

# %%
spark = SparkSession.builder.appName('Demo').getOrCreate() # create a app and app name is demo

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://286b92df9a84:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Demo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv('/content/test1.csv') # read the spark file

# %%
df.show() # show the data this is by deffold header like this
# Out:
# +--------+---+----------+------+
# |     _c0|_c1|       _c2|   _c3|
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df=spark.read.option('header', 'true').csv('test1.csv')# wan the enter this line than show the data than header is like this
df.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)

# %%
df.head(2) # this is show the first 2 row the show
# wan the not to add 2 than show the by deffold 5 data show
# Out:
# [Row(Name='Ben', age='31', Experience='10', Salary='30000'),
#  Row(Name='Srikanth', age='30', Experience='8', Salary='25000')]
